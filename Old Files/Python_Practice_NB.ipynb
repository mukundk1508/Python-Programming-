# %%
##Starting python.
#print("Hello! This is a python program.")
## print() is an output function to print values in the console.
#value = input("Enter a value to be printed=> ")
#print(f"The value which has been entered is {value}!!")
##This is what you call an F-string 
##input is used to take values from the user by means of Keyboard. 
#print(value.title())
#print(value.upper())
#print(value.lower())
#print(value)
##upper() and lower() methods do not change the original value.

#message=f"Hello This is {value.title()}"
##title () method will capitalize the first letters of the word like the title of a book
#print(message)

#rstrip and lstrip
"""
str1="python "
str2="python"
str3=str1.rstrip()
bool_val=(str1==str2)
print(bool_val)
bool_val=(str1.rstrip()==str2)
print(bool_val)
##rstrip() removes the white spaces from the right and makes sures that there are no more white spaces
str1="   python"
str2="python"
if str1 == str2:
    print("Both are equal")
elif str1.lstrip()==str2:
    print("There were some white spaces to the left of str1")
"""
# Out:
# '\nstr1="python "\nstr2="python"\nstr3=str1.rstrip()\nbool_val=(str1==str2)\nprint(bool_val)\nbool_val=(str1.rstrip()==str2)\nprint(bool_val)\n##rstrip() removes the white spaces from the right and makes sures that there are no more white spaces\nstr1="   python"\nstr2="python"\nif str1 == str2:\n    print("Both are equal")\nelif str1.lstrip()==str2:\n    print("There were some white spaces to the left of str1")\n'
